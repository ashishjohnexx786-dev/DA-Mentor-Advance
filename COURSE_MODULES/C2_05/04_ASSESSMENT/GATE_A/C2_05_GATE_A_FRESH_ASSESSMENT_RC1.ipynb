# %% [markdown]
# # C2-05 Gate A - Retail Orders Automation RC1
#
# **Fresh full assessment. Closed-book first attempt.**
#
# Build a recurring retail order-reporting pipeline for regional operations.
#
# You must deliver:
# 1. explicit config/paths and expected input files
# 2. modular discovery/load/clean/validate/enrich/report functions
# 3. schema/type handling and malformed-input decision
# 4. master-key uniqueness check before merge + unmatched-key evidence
# 5. deterministic lineage and row/total controls
# 6. useful logging and structured validation JSON
# 7. final output only after critical validation PASS
# 8. second unchanged rerun proves no duplicate business result
# 9. run manifest with Python/pandas versions, inputs and output evidence
# 10. 90-second defense
#
# **Critical rule:** Do not solve a dirty master key by silently dropping duplicates or switching to a many-to-many merge. Do not publish after unresolved critical checks.

# %%
from pathlib import Path
import pandas as pd, json, logging, hashlib, platform

# YOUR INDEPENDENT GATE WORK BELOW

# %% [markdown]
# ## Defense
# Explain input/output grain, file scope, duplicate/unmatched behavior, validation gate, rerun proof and reproducibility evidence.
