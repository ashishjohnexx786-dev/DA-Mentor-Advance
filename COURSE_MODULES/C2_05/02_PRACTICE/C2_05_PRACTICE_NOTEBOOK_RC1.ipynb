# %% [markdown]
# # C2-05 Python Automation for Analysts - Practice Notebook RC1
#
# **Rule:** Read the matching Teaching Book lesson first. Save your genuine attempt before opening the protected review.
#
# Target references: Python 3.14.7 / pandas 3.0.5. This notebook intentionally uses conservative APIs so the practice can also run on recent earlier versions.
#
# Set `PRACTICE_ROOT` to the extracted practice-data folder. Do not overwrite raw files or the reference Excel template.

# %%
from pathlib import Path
import json, logging, platform, hashlib
import pandas as pd

PRACTICE_ROOT = Path("PRACTICE_DATA_RC1")  # change only if your extracted folder is elsewhere
print("Python:", platform.python_version())
print("pandas:", pd.__version__)
print("Practice root exists:", PRACTICE_ROOT.exists())

# %% [markdown]
# ---
# ## P-PYA1 - Writing reusable analyst scripts
#
# **Independent task:** Refactor a one-off monthly sales load/clean/export into load_sales(), clean_sales(), validate_sales(), write_output() and main(). Run from a clean kernel/process twice. Inject a missing-input failure.
#
# Before coding, write:
# - input grain(s):
# - output grain:
# - expected success signal:
# - likely failure mode:
# - independent validation:

# %%
# P-PYA1 - YOUR GENUINE ATTEMPT
# Keep your first attempt. Do not paste a protected review solution here.

# %% [markdown]
# **Evidence before review**
# - clean/runnable result:
# - validation output:
# - failure/recovery evidence:
# - 60-90 second explain-back note:
# - status: NOT YET / DEVELOPING / MASTERED

# %% [markdown]
# ---
# ## P-PYA2 - Functions and modular code
#
# **Independent task:** Create normalize_channel(), require_columns(), calculate_net_sales(), summarize_by_region(). Add normal + edge/failure assertions.
#
# Before coding, write:
# - input grain(s):
# - output grain:
# - expected success signal:
# - likely failure mode:
# - independent validation:

# %%
# P-PYA2 - YOUR GENUINE ATTEMPT
# Keep your first attempt. Do not paste a protected review solution here.

# %% [markdown]
# **Evidence before review**
# - clean/runnable result:
# - validation output:
# - failure/recovery evidence:
# - 60-90 second explain-back note:
# - status: NOT YET / DEVELOPING / MASTERED

# %% [markdown]
# ---
# ## P-PYA3 - Robust pandas transformations
#
# **Independent task:** Load sales_malformed_numeric.csv. Parse dates/numerics deliberately. Decide fail vs quarantine for 'not_available'. Prove calculated net_sales reconciliation.
#
# Before coding, write:
# - input grain(s):
# - output grain:
# - expected success signal:
# - likely failure mode:
# - independent validation:

# %%
# P-PYA3 - YOUR GENUINE ATTEMPT
# Keep your first attempt. Do not paste a protected review solution here.

# %% [markdown]
# **Evidence before review**
# - clean/runnable result:
# - validation output:
# - failure/recovery evidence:
# - 60-90 second explain-back note:
# - status: NOT YET / DEVELOPING / MASTERED

# %% [markdown]
# ---
# ## P-PYA4 - Multi-file processing
#
# **Independent task:** Discover ONLY approved Apr-Jun sales files. Produce expected-vs-actual file list, schema checks, source_file lineage and per-file row reconciliation. Do not ingest backup/drift.
#
# Before coding, write:
# - input grain(s):
# - output grain:
# - expected success signal:
# - likely failure mode:
# - independent validation:

# %%
# P-PYA4 - YOUR GENUINE ATTEMPT
# Keep your first attempt. Do not paste a protected review solution here.

# %% [markdown]
# **Evidence before review**
# - clean/runnable result:
# - validation output:
# - failure/recovery evidence:
# - 60-90 second explain-back note:
# - status: NOT YET / DEVELOPING / MASTERED

# %% [markdown]
# ---
# ## P-PYA5 - Excel automation workflows
#
# **Independent task:** Create a NEW regional Excel report. Do not overwrite the reference template. Re-read your saved workbook and reconcile rows/regions/net_sales/transactions.
#
# Before coding, write:
# - input grain(s):
# - output grain:
# - expected success signal:
# - likely failure mode:
# - independent validation:

# %%
# P-PYA5 - YOUR GENUINE ATTEMPT
# Keep your first attempt. Do not paste a protected review solution here.

# %% [markdown]
# **Evidence before review**
# - clean/runnable result:
# - validation output:
# - failure/recovery evidence:
# - 60-90 second explain-back note:
# - status: NOT YET / DEVELOPING / MASTERED

# %% [markdown]
# ---
# ## P-PYA6 - CSV and JSON handling
#
# **Independent task:** Normalize nested_orders.json to one row per order item. Reconcile flattened rows to independent nested item count. Then handle changed optional-missing JSON.
#
# Before coding, write:
# - input grain(s):
# - output grain:
# - expected success signal:
# - likely failure mode:
# - independent validation:

# %%
# P-PYA6 - YOUR GENUINE ATTEMPT
# Keep your first attempt. Do not paste a protected review solution here.

# %% [markdown]
# **Evidence before review**
# - clean/runnable result:
# - validation output:
# - failure/recovery evidence:
# - 60-90 second explain-back note:
# - status: NOT YET / DEVELOPING / MASTERED

# %% [markdown]
# ---
# ## P-PYA7 - APIs for analysts
#
# **Independent task:** First parse local api_response.json offline. Then write fetch_json(url, timeout=15) with raise_for_status and specific Requests error translation. Live network call is optional.
#
# Before coding, write:
# - input grain(s):
# - output grain:
# - expected success signal:
# - likely failure mode:
# - independent validation:

# %%
# P-PYA7 - YOUR GENUINE ATTEMPT
# Keep your first attempt. Do not paste a protected review solution here.

# %% [markdown]
# **Evidence before review**
# - clean/runnable result:
# - validation output:
# - failure/recovery evidence:
# - 60-90 second explain-back note:
# - status: NOT YET / DEVELOPING / MASTERED

# %% [markdown]
# ---
# ## P-PYA8 - Error handling and defensive scripts
#
# **Independent task:** Inject missing file, missing required column, duplicate customer key and malformed numeric data. Define fail/quarantine behavior; prove critical failure withholds final output.
#
# Before coding, write:
# - input grain(s):
# - output grain:
# - expected success signal:
# - likely failure mode:
# - independent validation:

# %%
# P-PYA8 - YOUR GENUINE ATTEMPT
# Keep your first attempt. Do not paste a protected review solution here.

# %% [markdown]
# **Evidence before review**
# - clean/runnable result:
# - validation output:
# - failure/recovery evidence:
# - 60-90 second explain-back note:
# - status: NOT YET / DEVELOPING / MASTERED

# %% [markdown]
# ---
# ## P-PYA9 - Logging and validation checks
#
# **Independent task:** Create run.log plus validation_results.json. Log run start/files/rows/validation/output decision. Validation records need check/status/observed/rule. Inject failed customer key uniqueness.
#
# Before coding, write:
# - input grain(s):
# - output grain:
# - expected success signal:
# - likely failure mode:
# - independent validation:

# %%
# P-PYA9 - YOUR GENUINE ATTEMPT
# Keep your first attempt. Do not paste a protected review solution here.

# %% [markdown]
# **Evidence before review**
# - clean/runnable result:
# - validation output:
# - failure/recovery evidence:
# - 60-90 second explain-back note:
# - status: NOT YET / DEVELOPING / MASTERED

# %% [markdown]
# ---
# ## P-PYA10 - Automated recurring reporting
#
# **Independent task:** Build run_weekly(config). Discover -> clean -> validate master -> merge with validate='many_to_one' -> checks -> publish/withhold -> log. Run twice unchanged and prove no duplicated business result.
#
# Before coding, write:
# - input grain(s):
# - output grain:
# - expected success signal:
# - likely failure mode:
# - independent validation:

# %%
# P-PYA10 - YOUR GENUINE ATTEMPT
# Keep your first attempt. Do not paste a protected review solution here.

# %% [markdown]
# **Evidence before review**
# - clean/runnable result:
# - validation output:
# - failure/recovery evidence:
# - 60-90 second explain-back note:
# - status: NOT YET / DEVELOPING / MASTERED

# %% [markdown]
# ---
# ## P-PYA11 - Reproducible analytical pipelines
#
# **Independent task:** Read config_example.json; record Python/pandas versions, exact input files and hashes, rows/checks/output hash in run_manifest.json. Move/change project root or start a clean process and reproduce.
#
# Before coding, write:
# - input grain(s):
# - output grain:
# - expected success signal:
# - likely failure mode:
# - independent validation:

# %%
# P-PYA11 - YOUR GENUINE ATTEMPT
# Keep your first attempt. Do not paste a protected review solution here.

# %% [markdown]
# **Evidence before review**
# - clean/runnable result:
# - validation output:
# - failure/recovery evidence:
# - 60-90 second explain-back note:
# - status: NOT YET / DEVELOPING / MASTERED
