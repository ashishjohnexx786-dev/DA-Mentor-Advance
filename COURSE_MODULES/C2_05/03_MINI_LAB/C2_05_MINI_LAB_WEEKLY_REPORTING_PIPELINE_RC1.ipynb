# %% [markdown]
# # C2-05 Mini-Lab - Weekly Analyst Reporting Pipeline RC1
#
# Complete **after PYA1-PYA11**.
#
# Scenario: Operations receives three approved monthly sales CSVs plus a dirty customer master. Build a repeatable reporting pipeline that produces a regional report only when critical controls pass.
#
# Required route:
# 1. config-driven input/output paths and expected files
# 2. deterministic file discovery + schema/lineage
# 3. robust pandas typing/cleaning
# 4. customer master key validation
# 5. many-to-one enrichment with unmatched evidence
# 6. structured validation results
# 7. useful run logging
# 8. new Excel/CSV output + round-trip reconciliation
# 9. run manifest with environment/input/output evidence
# 10. second unchanged run proves rerun safety
# 11. failure injection blocks final release

# %%
from pathlib import Path
import pandas as pd, json, logging, hashlib, platform

PRACTICE_ROOT = Path("PRACTICE_DATA_RC1")
# YOUR INDEPENDENT PIPELINE BELOW

# %% [markdown]
# ## Required defense
# Explain in 90 seconds:
# - What does one output row mean?
# - Which file/key/schema failure would block release?
# - How do you know rerunning did not duplicate business data?
# - What evidence lets another analyst reproduce this run?
